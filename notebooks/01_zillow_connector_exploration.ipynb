# %%
import pandas as pd
from pathlib import Path

processed_path = Path("../data/processed/all_properties_normalized.csv")
df = pd.read_csv(processed_path)

df.head()
# Out:
#    property_id      zpid                                     address  \
# 0     59147121  59147121          41 Brown Ave, Roslindale, MA 02131
# 1     59210672  59210672   15 S Fairview St #3, Roslindale, MA 02131
# 2     59143097  59143097     136A Belgrade Ave, Roslindale, MA 02131
# 3     81775911  81775911         61 Cummins Hwy #2, Boston, MA 02131
# 4     59141211  59141211  45 Harrison St APT B, Roslindale, MA 02131
#
#          city state  zip_code   latitude  longitude  is_bad_geocode  \
# 0  Roslindale    MA      2131  42.281094 -71.122986             NaN
# 1  Roslindale    MA      2131  42.287620 -71.132010             NaN
# 2  Roslindale    MA      2131  42.286003 -71.136260             NaN
# 3      Boston    MA      2131  42.284970 -71.126060             NaN
# 4  Roslindale    MA      2131  42.288406 -71.120790             NaN
#
#   home_status  ... missing_home_type missing_lat_long  missing_zestimate  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 47 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   property_id                            10 non-null     int64
#  1   zpid                                   10 non-null     int64
#  2   address                                10 non-null     str
#  3   city                                   10 non-null     str
#  4   state                                  10 non-null     str
#  5   zip_code                               10 non-null     int64
#  6   latitude                               9 non-null      float64
#  7   longitude                              9 non-null      float64
#  8   is_bad_geocode                         0 non-null      float64
#  9   home_status                            10 non-null     str
#  10  status_text                            10 non-null     str
# ...

# %%
df[["address", "city", "home_type", "price", "beds", "baths", "square_feet", "price_per_sqft"]].head(20)
# Out:
#                                              address        city  \
# 0                 41 Brown Ave, Roslindale, MA 02131  Roslindale
# 1          15 S Fairview St #3, Roslindale, MA 02131  Roslindale
# 2            136A Belgrade Ave, Roslindale, MA 02131  Roslindale
# 3                61 Cummins Hwy #2, Boston, MA 02131      Boston
# 4         45 Harrison St APT B, Roslindale, MA 02131  Roslindale
# 5      737 American Legion Hwy, Roslindale, MA 02131  Roslindale
# 6              74-76 Poplar St, Roslindale, MA 02131  Roslindale
# 7                     74-76 Poplar, Boston, MA 02131      Boston
# 8  596 American Legion Hwy APT 3, Roslindale, MA ...  Roslindale
# 9        (undisclosed Address), Roslindale, MA 02131  Roslindale
#
#        home_type    price  beds  baths  square_feet  price_per_sqft
# 0  single_family  1650000     5      3         3117      529.355149
# 1          condo   583500     3      1         1475      395.593220
# ...
